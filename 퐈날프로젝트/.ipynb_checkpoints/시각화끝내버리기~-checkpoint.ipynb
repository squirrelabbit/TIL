# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as ny

# %%
sns.set(style="whitegrid", font_scale=1, font='Malgun Gothic')
# %matplotlib inline

# %% [markdown]
# ## Cluster3_평균

# %%
df_3 = pd.read_excel('Cluster3_평균.xlsx')
df_3
# Out:
#           Avg_3   의정부시    오산시    파주시    화성시    광주시    양주시
# 0     80.100000   77.7   83.2   82.3   73.0   82.4   82.0
# 1     79.816667   77.4   83.0   81.9   72.9   82.0   81.7
# 2     79.583333   76.9   82.9   81.6   72.8   81.9   81.4
# 3     79.516667   76.4   82.9   80.6   73.2   82.3   81.7
# 4     79.633333   76.4   82.9   80.7   73.6   82.3   81.9
# ..          ...    ...    ...    ...    ...    ...    ...
# 105  108.783333  106.5  114.1  105.9  110.9  106.8  108.5
# 106  109.833333  107.2  115.9  106.9  111.6  107.9  109.5
# 107  110.183333  107.4  116.7  107.2  111.6  108.4  109.8
# 108  110.283333  107.4  116.8  107.5  111.5  108.7  109.8
# 109  110.183333  107.3  116.6  107.8  111.0  108.7  109.7
#
# [110 rows x 7 columns]

# %%
df_3['Avg_3'].plot(figsize=(10, 5),color='yellow',lw=8)
df_3['의정부시'].plot(figsize=(10, 5))
df_3['오산시'].plot(figsize=(10, 5))
df_3['파주시'].plot(figsize=(10, 5))
df_3['화성시'].plot(figsize=(10, 5))
df_3['광주시'].plot(figsize=(10, 5))
df_3['양주시'].plot(figsize=(10, 5))
plt.legend()

# %% [markdown]
# ## Cluster2_평균

# %%
df_2 = pd.read_excel('Cluster2_평균.xlsx')
df_2
# Out:
#           Avg_2    평택시   동두천시    이천시    안성시    포천시    여주시
# 0     93.900000   92.6   92.6   89.2   92.6   93.6  102.8
# 1     93.666667   92.5   90.9   89.4   92.8   93.6  102.8
# 2     93.550000   92.4   90.1   89.7   92.8   93.6  102.7
# 3     93.766667   92.4   90.0   90.1   93.5   93.9  102.7
# 4     94.116667   92.4   89.8   90.4   93.8   94.7  103.6
# ..          ...    ...    ...    ...    ...    ...    ...
# 105  108.650000  111.7  107.3  107.8  112.6  107.3  105.2
# 106  110.166667  113.2  107.7  110.3  114.8  108.4  106.6
# 107  111.033333  114.1  107.5  112.3  116.1  109.0  107.2
# 108  111.383333  114.3  107.5  113.3  116.9  109.2  107.1
# 109  111.550000  114.3  107.4  114.2  117.0  109.3  107.1
#
# [110 rows x 7 columns]

# %%
df_2['Avg_2'].plot(figsize=(10, 5),color='steelblue',lw=8)
df_2['평택시'].plot(figsize=(10, 5))
df_2['동두천시'].plot(figsize=(10, 5))
df_2['이천시'].plot(figsize=(10, 5))
df_2['안성시'].plot(figsize=(10, 5))
df_2['포천시'].plot(figsize=(10, 5))
df_2['여주시'].plot(figsize=(10, 5))
plt.legend()

# %% [markdown]
# ## Cluster1_평균

# %%
df_1 = pd.read_excel('Cluster1_평균.xlsx')
df_1
# Out:
#          Avg_1    수원시    성남시    안양시    부천시    광명시    안산시    고양시    과천시    구리시  \
# 0     64.75625   63.4   67.8   60.5   68.1   53.0   66.8   69.5   63.4   58.9
# 1     64.42500   63.3   67.2   60.2   67.7   52.9   66.6   69.0   63.1   58.3
# 2     64.22500   63.2   66.9   60.0   67.4   52.6   66.3   68.6   63.2   58.0
# 3     64.30000   63.3   67.1   59.8   67.4   52.6   66.3   68.1   64.5   58.1
# 4     64.49375   63.4   67.5   59.6   67.6   52.9   66.6   68.1   64.8   58.3
# ..         ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 105  107.45625  108.4  104.3  110.5  108.7  106.7  109.3  106.7  102.6  105.3
# 106  108.45625  109.5  104.8  111.7  110.2  107.3  110.7  107.6  103.1  106.2
# 107  108.79375  109.8  105.1  112.0  110.8  107.4  111.2  108.0  103.5  106.4
# 108  108.75000  109.8  105.1  111.8  110.8  107.3  111.3  108.1  103.4  106.3
# 109  108.65000  109.6  105.0  111.6  110.7  107.3  111.3  108.0  103.4  106.3
#
# ...

# %%
df_1['Avg_1'].plot(figsize=(10, 8),color='orange',lw=8)
df_1['수원시'].plot(figsize=(10, 8))
df_1['성남시'].plot(figsize=(10, 8))
df_1['안양시'].plot(figsize=(10, 8))
df_1['부천시'].plot(figsize=(10, 8))
df_1['광명시'].plot(figsize=(10, 8))
df_1['안산시'].plot(figsize=(10, 8))
df_1['고양시'].plot(figsize=(10, 8))
df_1['과천시'].plot(figsize=(10, 8))
df_1['구리시'].plot(figsize=(10, 8))
df_1['남양주시'].plot(figsize=(10, 8))
df_1['시흥시'].plot(figsize=(10, 8))
df_1['군포시'].plot(figsize=(10, 8))
df_1['의왕시'].plot(figsize=(10, 8))
df_1['하남시'].plot(figsize=(10, 8))
df_1['용인시'].plot(figsize=(10, 8))
df_1['김포시'].plot(figsize=(10, 8))
plt.legend()

# %% [markdown]
# ## 경기도와 각 Clusters 평균 비교

# %%
df_g = pd.read_excel('경기도.xlsx')
df_g
# Out:
#        경기도      Avg_1       Avg_2       Avg_3
# 0     70.2   64.75625   93.900000   80.100000
# 1     69.9   64.42500   93.666667   79.816667
# 2     69.7   64.22500   93.550000   79.583333
# 3     69.6   64.30000   93.766667   79.516667
# 4     69.8   64.49375   94.116667   79.633333
# ..     ...        ...         ...         ...
# 105  108.0  107.45625  108.650000  108.783333
# 106  109.1  108.45625  110.166667  109.833333
# 107  109.5  108.79375  111.033333  110.183333
# 108  109.5  108.75000  111.383333  110.283333
# 109  109.4  108.65000  111.550000  110.183333
#
# [110 rows x 4 columns]

# %%
df_g['경기도'].plot(figsize=(10, 5),color='pink',lw=8)
df_g['Avg_1'].plot(figsize=(10, 5))
df_g['Avg_2'].plot(figsize=(10, 5))
df_g['Avg_3'].plot(figsize=(10, 5))
plt.legend()
