# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as ny

# %%
sns.set(style="whitegrid", font_scale=1, font='Malgun Gothic')

# %matplotlib inline

# %%
df = pd.read_excel('통합 문서11.xlsx')
df
# Out:
#        행정구역별    경기도  　　　수원시  　　　성남시  　　　의정부시  　　　안양시  　　　부천시  　　　광명시  　　　평택시  \
# 0    2013.01   70.2    63.4    67.8     77.7    60.5    68.1    53.0    92.6
# 1    2013.02   69.9    63.3    67.2     77.4    60.2    67.7    52.9    92.5
# 2    2013.03   69.7    63.2    66.9     76.9    60.0    67.4    52.6    92.4
# 3    2013.04   69.6    63.3    67.1     76.4    59.8    67.4    52.6    92.4
# 4    2013.05   69.8    63.4    67.5     76.4    59.6    67.6    52.9    92.4
# ..       ...    ...     ...     ...      ...     ...     ...     ...     ...
# 105  2021.10  108.0   108.4   104.3    106.5   110.5   108.7   106.7   111.7
# 106  2021.11  109.1   109.5   104.8    107.2   111.7   110.2   107.3   113.2
# 107  2021.12  109.5   109.8   105.1    107.4   112.0   110.8   107.4   114.1
# 108  2022.01  109.5   109.8   105.1    107.4   111.8   110.8   107.3   114.3
# 109  2022.02  109.4   109.6   105.0    107.3   111.6   110.7   107.3   114.3
#
# ...

# %%
group_count = df.groupby(["행정구역별"]).sum().unstack()
group_count
# Out:
#         행정구역별
# 경기도     2013.01     70.2
#         2013.02     69.9
#         2013.03     69.7
#         2013.04     69.6
#         2013.05     69.8
#                    ...
# 　　　여주시  2021.10    105.2
#         2021.11    106.6
#         2021.12    107.2
#         2022.01    107.1
#         2022.02    107.1
# Length: 3190, dtype: float64

# %%
df.plot(figsize=(20, 50))
# Out:
# <AxesSubplot:>
