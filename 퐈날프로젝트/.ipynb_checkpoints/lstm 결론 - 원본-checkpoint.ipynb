# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as pdr
import matplotlib.pyplot as plt
import datetime
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# GPU setting

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#print(torch.cuda.get_device_name(0)) #Google colab = TESLA T4

# %%
 # Data load

df = pd.read_csv('경기도_clustered.csv',index_col = 0,encoding = 'cp949')
df = df.T
df
# Out:
# date             수원시       성남시      의정부시       안양시       부천시       광명시  \
# 2013-01-01  63.40000  67.80000  77.70000  60.50000  68.10000  53.00000
# 2013-02-01  63.30000  67.20000  77.40000  60.20000  67.70000  52.90000
# 2013-03-01  63.20000  66.90000  76.90000  60.00000  67.40000  52.60000
# 2013-04-01  63.30000  67.10000  76.40000  59.80000  67.40000  52.60000
# 2013-05-01  63.40000  67.50000  76.40000  59.60000  67.60000  52.90000
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-01 109.50000 104.80000 107.20000 111.70000 110.20000 107.30000
# 2021-12-01 109.80000 105.10000 107.40000 112.00000 110.80000 107.40000
# 2022-01-01 109.80000 105.10000 107.40000 111.80000 110.80000 107.30000
# 2022-02-01 109.60000 105.00000 107.30000 111.60000 110.70000 107.30000
# cluster      0.00000   0.00000   2.00000   0.00000   0.00000   0.00000
#
# date             평택시      동두천시       안산시       고양시  ...       이천시       안성시  \
# 2013-01-01  92.60000  92.60000  66.80000  69.50000  ...  89.20000  92.60000
# 2013-02-01  92.50000  90.90000  66.60000  69.00000  ...  89.40000  92.80000
# 2013-03-01  92.40000  90.10000  66.30000  68.60000  ...  89.70000  92.80000
# 2013-04-01  92.40000  90.00000  66.30000  68.10000  ...  90.10000  93.50000
# 2013-05-01  92.40000  89.80000  66.60000  68.10000  ...  90.40000  93.80000
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-11-01 113.20000 107.70000 110.70000 107.60000  ... 110.30000 114.80000
# 2021-12-01 114.10000 107.50000 111.20000 108.00000  ... 112.30000 116.10000
# 2022-01-01 114.30000 107.50000 111.30000 108.10000  ... 113.30000 116.90000
# 2022-02-01 114.30000 107.40000 111.30000 108.00000  ... 114.20000 117.00000
# cluster      1.00000   1.00000   0.00000   0.00000  ...   1.00000   1.00000
#
# date             김포시       화성시       광주시       양주시       여주시       포천시  \
# 2013-01-01  71.10000  73.00000  82.40000  82.00000 102.80000  93.60000
# 2013-02-01  70.90000  72.90000  82.00000  81.70000 102.80000  93.60000
# 2013-03-01  70.80000  72.80000  81.90000  81.40000 102.70000  93.60000
# 2013-04-01  70.70000  73.20000  82.30000  81.70000 102.70000  93.90000
# 2013-05-01  71.00000  73.60000  82.30000  81.90000 103.60000  94.70000
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-01 105.30000 111.60000 107.90000 109.50000 106.60000 108.40000
# 2021-12-01 105.60000 111.60000 108.40000 109.80000 107.20000 109.00000
# 2022-01-01 105.60000 111.50000 108.70000 109.80000 107.10000 109.20000
# 2022-02-01 105.60000 111.00000 108.70000 109.70000 107.10000 109.30000
# cluster      0.00000   0.00000   2.00000   2.00000   1.00000   1.00000
#
# date             의왕시       오산시
# 2013-01-01  59.70000  83.20000
# 2013-02-01  59.10000  83.00000
# 2013-03-01  58.70000  82.90000
# 2013-04-01  58.60000  82.90000
# 2013-05-01  58.80000  82.90000
# ...              ...       ...
# 2021-11-01 112.90000 115.90000
# 2021-12-01 113.00000 116.70000
# 2022-01-01 113.00000 116.80000
# 2022-02-01 112.90000 116.60000
# cluster      0.00000   2.00000
#
# [111 rows x 28 columns]

# %%
data = pd.read_csv('경기도변수.csv',index_col = 0)
data
# Out:
#                seoul     Avg_1     Avg_2     Avg_3       MMI       CPI  \
# date
# 2013-01-01  73.50000  64.75625  93.90000  80.10000 102.86800  92.72800
# 2013-02-01  73.20000  64.42500  93.66667  79.80000  90.00900  93.03800
# 2013-03-01  73.10000  64.22500  93.55000  79.60000 101.38800  92.95200
# 2013-04-01  73.20000  64.30000  93.76667  79.50000 101.29500  92.82300
# 2013-05-01  73.40000  64.49375  94.11667  79.60000 102.31300  92.82300
# ...              ...       ...       ...       ...       ...       ...
# 2021-10-01 103.50000 107.45625 108.65000 108.80000 114.80000 103.35000
# 2021-11-01 104.10000 108.45625 110.16667 109.80000 119.30000 103.87000
# 2021-12-01 104.40000 108.79375 111.03333 110.20000 126.70000 104.04000
# 2022-01-01 104.40000 108.75000 111.38333 110.30000 115.10000 104.69000
# 2022-02-01 104.30000 108.65000 111.55000 110.20000 107.00000 105.30000
#
#               대출금리  전세가격지수 전국   전세가격지수 경기도         환율         M2        코스피  \
# date
# 2013-01-01 5.78000    82.68933    76.00764 1089.00000 1841.10000 1961.90000
# 2013-02-01 5.66000    82.87118    76.10804 1083.00000 1857.10000 2026.50000
# 2013-03-01 5.54000    83.16272    76.37669 1111.00000 1862.40000 2004.90000
# 2013-04-01 5.42000    83.55404    76.85819 1101.00000 1867.70000 1964.00000
# 2013-05-01 5.24000    83.79708    77.09053 1129.70000 1870.30000 2001.05000
# ...            ...         ...         ...        ...        ...        ...
# 2021-10-01 3.47000   102.45093   103.90395 1168.60000 3543.40000 2970.68000
# 2021-11-01 3.58000   102.91790   104.54323 1187.90000 3594.70000 2839.01000
# 2021-12-01 3.68000   103.17831   104.79809 1188.80000 3620.10000 2977.65000
# 2022-01-01 3.75000   103.25089   104.79087 1205.50000 3634.30000 2663.34000
# 2022-02-01 3.90000   103.24944   104.74586 1202.30000 3656.10000 2699.18000
#
#                   코스닥         건축허용면적  거래량 전국  거래량 경기
# date
# 2013-01-01  503.67000  8413721.00000   54632   13631
# 2013-02-01  535.87000  7268443.00000   65640   14925
# 2013-03-01  555.02000 10160177.00000   87563   17718
# 2013-04-01  563.87000  9757932.00000  106498   22790
# 2013-05-01  577.87000 10837979.00000  120393   25910
# ...               ...            ...     ...     ...
# 2021-10-01  992.33000 14689855.00000  119686   29187
# 2021-11-01  965.63000 14483042.00000  111172   26593
# 2021-12-01 1033.98000 19169150.00000  101766   25669
# 2022-01-01  872.87000 13736304.00000   87825   20544
# 2022-02-01  881.07000 11862344.00000   85733   18484
#
# [110 rows x 16 columns]

# %%
train = data.copy()
train
# Out:
#                seoul     Avg_1     Avg_2     Avg_3       MMI       CPI  \
# date
# 2013-01-01  73.50000  64.75625  93.90000  80.10000 102.86800  92.72800
# 2013-02-01  73.20000  64.42500  93.66667  79.80000  90.00900  93.03800
# 2013-03-01  73.10000  64.22500  93.55000  79.60000 101.38800  92.95200
# 2013-04-01  73.20000  64.30000  93.76667  79.50000 101.29500  92.82300
# 2013-05-01  73.40000  64.49375  94.11667  79.60000 102.31300  92.82300
# ...              ...       ...       ...       ...       ...       ...
# 2021-10-01 103.50000 107.45625 108.65000 108.80000 114.80000 103.35000
# 2021-11-01 104.10000 108.45625 110.16667 109.80000 119.30000 103.87000
# 2021-12-01 104.40000 108.79375 111.03333 110.20000 126.70000 104.04000
# 2022-01-01 104.40000 108.75000 111.38333 110.30000 115.10000 104.69000
# 2022-02-01 104.30000 108.65000 111.55000 110.20000 107.00000 105.30000
#
#               대출금리  전세가격지수 전국   전세가격지수 경기도         환율         M2        코스피  \
# date
# 2013-01-01 5.78000    82.68933    76.00764 1089.00000 1841.10000 1961.90000
# 2013-02-01 5.66000    82.87118    76.10804 1083.00000 1857.10000 2026.50000
# 2013-03-01 5.54000    83.16272    76.37669 1111.00000 1862.40000 2004.90000
# 2013-04-01 5.42000    83.55404    76.85819 1101.00000 1867.70000 1964.00000
# 2013-05-01 5.24000    83.79708    77.09053 1129.70000 1870.30000 2001.05000
# ...            ...         ...         ...        ...        ...        ...
# 2021-10-01 3.47000   102.45093   103.90395 1168.60000 3543.40000 2970.68000
# 2021-11-01 3.58000   102.91790   104.54323 1187.90000 3594.70000 2839.01000
# 2021-12-01 3.68000   103.17831   104.79809 1188.80000 3620.10000 2977.65000
# 2022-01-01 3.75000   103.25089   104.79087 1205.50000 3634.30000 2663.34000
# 2022-02-01 3.90000   103.24944   104.74586 1202.30000 3656.10000 2699.18000
#
#                   코스닥         건축허용면적  거래량 전국  거래량 경기
# date
# 2013-01-01  503.67000  8413721.00000   54632   13631
# 2013-02-01  535.87000  7268443.00000   65640   14925
# 2013-03-01  555.02000 10160177.00000   87563   17718
# 2013-04-01  563.87000  9757932.00000  106498   22790
# 2013-05-01  577.87000 10837979.00000  120393   25910
# ...               ...            ...     ...     ...
# 2021-10-01  992.33000 14689855.00000  119686   29187
# 2021-11-01  965.63000 14483042.00000  111172   26593
# 2021-12-01 1033.98000 19169150.00000  101766   25669
# 2022-01-01  872.87000 13736304.00000   87825   20544
# 2022-02-01  881.07000 11862344.00000   85733   18484
#
# [110 rows x 16 columns]

# %%
train.corr()
# Out:
#               seoul    Avg_1    Avg_2    Avg_3      MMI      CPI     대출금리  \
# seoul       1.00000  0.90937  0.22791  0.77387  0.65565  0.98536 -0.78876
# Avg_1       0.90937  1.00000  0.43014  0.95232  0.65904  0.91431 -0.73825
# Avg_2       0.22791  0.43014  1.00000  0.63663  0.26381  0.31619 -0.26385
# Avg_3       0.77387  0.95232  0.63663  1.00000  0.61770  0.80261 -0.59546
# MMI         0.65565  0.65904  0.26381  0.61770  1.00000  0.64364 -0.50888
# CPI         0.98536  0.91431  0.31619  0.80261  0.64364  1.00000 -0.78866
# 대출금리       -0.78876 -0.73825 -0.26385 -0.59546 -0.50888 -0.78866  1.00000
# 전세가격지수 전국   0.82194  0.85927  0.62986  0.82992  0.59033  0.86051 -0.88344
# 전세가격지수 경기도  0.83350  0.86416  0.60502  0.82501  0.59217  0.86782 -0.89777
# 환율          0.51119  0.45403  0.12227  0.35248  0.22583  0.47790 -0.55747
# M2          0.98395  0.95073  0.25843  0.82588  0.66092  0.97765 -0.82740
# 코스피         0.71342  0.82543  0.40436  0.83377  0.59047  0.73679 -0.57529
# 코스닥         0.80426  0.85191  0.41053  0.80558  0.57564  0.80020 -0.73038
# 건축허용면적      0.12069  0.21349  0.46749  0.25581  0.37032  0.13549 -0.41693
# 거래량 전국      0.27725  0.14592 -0.12229 -0.00010  0.31797  0.25272 -0.54202
# 거래량 경기      0.46107  0.22341 -0.11360  0.04684  0.35594  0.43478 -0.61100
#
#             전세가격지수 전국   전세가격지수 경기도       환율       M2      코스피      코스닥  \
# seoul          0.82194     0.83350  0.51119  0.98395  0.71342  0.80426
# Avg_1          0.85927     0.86416  0.45403  0.95073  0.82543  0.85191
# Avg_2          0.62986     0.60502  0.12227  0.25843  0.40436  0.41053
# Avg_3          0.82992     0.82501  0.35248  0.82588  0.83377  0.80558
# MMI            0.59033     0.59217  0.22583  0.66092  0.59047  0.57564
# CPI            0.86051     0.86782  0.47790  0.97765  0.73679  0.80020
# 대출금리          -0.88344    -0.89777 -0.55747 -0.82740 -0.57529 -0.73038
# 전세가격지수 전국      1.00000     0.99877  0.44409  0.85400  0.73851  0.83238
# 전세가격지수 경기도     0.99877     1.00000  0.46612  0.86609  0.73232  0.83338
# 환율             0.44409     0.46612  1.00000  0.52514  0.03280  0.22826
# M2             0.85400     0.86609  0.52514  1.00000  0.75119  0.82234
# 코스피            0.73851     0.73232  0.03280  0.75119  1.00000  0.88382
# 코스닥            0.83238     0.83338  0.22826  0.82234  0.88382  1.00000
# 건축허용면적         0.45508     0.44888  0.16604  0.16326  0.22008  0.34489
# 거래량 전국         0.31973     0.33749  0.12524  0.28422  0.19207  0.28606
# 거래량 경기         0.41120     0.42914  0.22564  0.41933  0.23006  0.34991
#
#              건축허용면적   거래량 전국   거래량 경기
# seoul       0.12069  0.27725  0.46107
# Avg_1       0.21349  0.14592  0.22341
# Avg_2       0.46749 -0.12229 -0.11360
# Avg_3       0.25581 -0.00010  0.04684
# MMI         0.37032  0.31797  0.35594
# CPI         0.13549  0.25272  0.43478
# 대출금리       -0.41693 -0.54202 -0.61100
# 전세가격지수 전국   0.45508  0.31973  0.41120
# 전세가격지수 경기도  0.44888  0.33749  0.42914
# 환율          0.16604  0.12524  0.22564
# M2          0.16326  0.28422  0.41933
# 코스피         0.22008  0.19207  0.23006
# 코스닥         0.34489  0.28606  0.34991
# 건축허용면적      1.00000  0.39492  0.28304
# 거래량 전국      0.39492  1.00000  0.89673
# 거래량 경기      0.28304  0.89673  1.00000

# %%
# Training/Test ratio = 7:3

Train_ratio = 0.7

Test_ratio = 0.3

# %%
result =  pd.DataFrame(data=[0,0,0,0],
                             index = ['MAE','RMSE','MAPE', 'R2'],
                             columns=['test'])
result
# Out:
#       test
# MAE      0
# RMSE     0
# MAPE     0
# R2       0

# %%
for i in range(28):
    cluster = int(df[df.columns[i]][-1])
    answer = []
    for num in range(11):
        if abs(train.corr()['Avg_{}'.format(cluster+1)][num])>=0.7:
            answer.append(num)
    
    col =[]
    for j in  answer:
        col.append(train.columns[j])
    train[col]
    
    x = train[col].replace(',','')
    y = df.iloc[:-1,i:i+1]
    
    
    # Data Division

    train_x = x.iloc[0:int(len(df)*Train_ratio),:]

    train_y = y.iloc[0:int(len(df)*Train_ratio),:]

    test_x = x.iloc[int(len(df)*Train_ratio):,:]

    test_y = y.iloc[int(len(df)*Train_ratio):,:]


    # Normalizing , 둘다 학습하여 성능비교할것

    minmax = MinMaxScaler()

    standard = StandardScaler()



    train_x = minmax.fit_transform(train_x)

    train_y = minmax.fit_transform(train_y)

    test_x = minmax.fit_transform(test_x)

    test_y = minmax.fit_transform(test_y)





    # Numpy array상태로는 학습이 불가능하므로, Torch Variable 형태로 변경(data/grad/grad_fn)

    train_x_tensor = Variable(torch.Tensor(train_x))

    train_y_tensor = Variable(torch.Tensor(train_y))

    

    test_x_tensor = Variable(torch.Tensor(test_x))

    test_y_tensor = Variable(torch.Tensor(test_y))

    

    train_x_tensor_final = torch.reshape(train_x_tensor, (train_x_tensor.shape[0], 1, train_x_tensor.shape[1]))

    train_y_tensor_final = torch.reshape(train_y_tensor, (train_y_tensor.shape[0], 1, train_y_tensor.shape[1]))

    test_x_tensor_final = torch.reshape(test_x_tensor, (test_x_tensor.shape[0], 1, test_x_tensor.shape[1]))

    test_y_tensor_final = torch.reshape(test_y_tensor,(test_y_tensor.shape[0], 1, test_y_tensor.shape[1]) )

    


    ## LSTM network modeling

    class LSTM_Jun(nn.Module):

        def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length) : 

            super(LSTM_Jun, self).__init__()

            self.num_classes = num_classes

            self.num_layers = num_layers

            self.input_size = input_size

            self.hidden_size = hidden_size

            self.seq_length = seq_length

            self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = num_layers, batch_first = True)

            self.layer_1 = nn.Linear(hidden_size, 256)

            self.layer_2 = nn.Linear(256,256)

            self.layer_3 = nn.Linear(256,128)

            self.layer_out = nn.Linear(128, num_classes)

            self.relu = nn.ReLU() #Activation Func



        def forward(self,x):

            h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device) #Hidden State

            c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device) #Internal Process States



            output, (hn, cn) = self.lstm(x, (h_0, c_0))



            hn = hn.view(-1, self.hidden_size) # Reshaping the data for starting LSTM network

            out = self.relu(hn) #pre-processing for first layer

            out = self.layer_1(out) # first layer

            out = self.relu(out) # activation func relu

            out = self.layer_2(out)

            out = self.relu(out)

            out = self.layer_3(out)

            out = self.relu(out)

            out = self.layer_out(out) #Output layer

            return out

 

    # Code Main

    num_epochs = 500
    learning_rate = 0.005

    input_size = int(len(x.columns))

    hidden_size = 2 # number of features in hidden state

    num_layers = 1

    num_classes = int(len(y.columns))



    LSTM_Jun = LSTM_Jun(num_classes, input_size, hidden_size, num_layers, train_x_tensor_final.shape[1]).to(device)



    loss_function = torch.nn.MSELoss()

    optimizer = torch.optim.Adam(LSTM_Jun.parameters(), lr = learning_rate)

 

    for epoch in range(num_epochs) : 

        outputs = LSTM_Jun.forward(train_x_tensor_final.to(device))

        optimizer.zero_grad()

        loss = loss_function(outputs, train_y_tensor.to(device))

        loss.backward()

        optimizer.step() # improve from loss = back propagation

        if epoch % 100 == 0 :

            print("Epoch : %d, loss : %1.5f" % (epoch, loss.item()))
            

    # Estimated Value

    test_predict = LSTM_Jun(test_x_tensor_final.to(device)) #Forward Pass

    predict_data = test_predict.data.detach().cpu().numpy() #numpy conversion

    predict_data = minmax.inverse_transform(predict_data) #inverse normalization(Min/Max)
    

    # Real Value

    real_data = test_y_tensor.data.numpy() # Real value

    real_data = minmax.inverse_transform(real_data) #inverse normalization 
    
    from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

    
    MAE = mean_absolute_error(predict_data, real_data)
    RMSE = np.sqrt(mean_squared_error(predict_data, real_data))
    R2 = r2_score(predict_data, real_data)
    MAPE= np.mean(np.abs((y_test - y_pred) / y_test))
    pd.options.display.float_format = '{:.5f}'.format
    label = df.columns[i]
    Result = pd.DataFrame(data=[MAE,RMSE, MAPE,R2],
                         index = ['MAE','RMSE','MAPE','R2'],
                         columns=[label])
        
    

    result = pd.concat([result,Result],axis = 1)
# Out:
# Epoch : 0, loss : 0.41266
# Epoch : 100, loss : 0.00102
# Epoch : 200, loss : 0.00110
# Epoch : 300, loss : 0.00018
# Epoch : 400, loss : 0.00015
# Epoch : 0, loss : 0.23372
# Epoch : 100, loss : 0.00101
# Epoch : 200, loss : 0.00062
# Epoch : 300, loss : 0.00030
# Epoch : 400, loss : 0.00023
# Epoch : 0, loss : 0.49794
# Epoch : 100, loss : 0.00151
# Epoch : 200, loss : 0.00060
# Epoch : 300, loss : 0.00036
# Epoch : 400, loss : 0.00032
# Epoch : 0, loss : 0.43309
# Epoch : 100, loss : 0.00041
# Epoch : 200, loss : 0.00031
# Epoch : 300, loss : 0.00020
# Epoch : 400, loss : 0.00014
# Epoch : 0, loss : 0.21698
# Epoch : 100, loss : 0.08791
# Epoch : 200, loss : 0.08791
# Epoch : 300, loss : 0.08791
# Epoch : 400, loss : 0.08791
# Epoch : 0, loss : 0.36313
# Epoch : 100, loss : 0.00236
# Epoch : 200, loss : 0.00058
# Epoch : 300, loss : 0.00027
# Epoch : 400, loss : 0.00051
# Epoch : 0, loss : 0.56745
# Epoch : 100, loss : 0.07302
# Epoch : 200, loss : 0.07302
# Epoch : 300, loss : 0.07302
# Epoch : 400, loss : 0.07302
# Epoch : 0, loss : 0.22823
# Epoch : 100, loss : 0.06341
# Epoch : 200, loss : 0.06100
# Epoch : 300, loss : 0.05978
# Epoch : 400, loss : 0.05636
# Epoch : 0, loss : 0.52295
# Epoch : 100, loss : 0.13815
# Epoch : 200, loss : 0.13814
# Epoch : 300, loss : 0.13814
# Epoch : 400, loss : 0.13814
# Epoch : 0, loss : 0.50080
# Epoch : 100, loss : 0.00097
# Epoch : 200, loss : 0.00088
# Epoch : 300, loss : 0.00076
# Epoch : 400, loss : 0.00071
# Epoch : 0, loss : 0.27912
# Epoch : 100, loss : 0.00164
# Epoch : 200, loss : 0.00068
# Epoch : 300, loss : 0.00031
# Epoch : 400, loss : 0.00034
# Epoch : 0, loss : 0.24566
# Epoch : 100, loss : 0.00107
# Epoch : 200, loss : 0.00091
# Epoch : 300, loss : 0.00029
# Epoch : 400, loss : 0.00019
# Epoch : 0, loss : 0.61208
# Epoch : 100, loss : 0.00074
# Epoch : 200, loss : 0.00055
# Epoch : 300, loss : 0.00043
# Epoch : 400, loss : 0.00036
# Epoch : 0, loss : 0.52959
# Epoch : 100, loss : 0.00084
# Epoch : 200, loss : 0.00036
# Epoch : 300, loss : 0.00026
# Epoch : 400, loss : 0.00023
# Epoch : 0, loss : 0.55999
# Epoch : 100, loss : 0.00235
# Epoch : 200, loss : 0.00169
# Epoch : 300, loss : 0.00155
# Epoch : 400, loss : 0.00143
# Epoch : 0, loss : 0.42389
# Epoch : 100, loss : 0.00210
# Epoch : 200, loss : 0.00064
# Epoch : 300, loss : 0.00052
# Epoch : 400, loss : 0.00041
# Epoch : 0, loss : 0.16979
# Epoch : 100, loss : 0.01803
# Epoch : 200, loss : 0.00194
# Epoch : 300, loss : 0.00183
# Epoch : 400, loss : 0.00103
# Epoch : 0, loss : 0.49582
# Epoch : 100, loss : 0.00379
# Epoch : 200, loss : 0.00189
# Epoch : 300, loss : 0.00180
# Epoch : 400, loss : 0.00153
# Epoch : 0, loss : 0.69379
# Epoch : 100, loss : 0.01175
# Epoch : 200, loss : 0.01130
# Epoch : 300, loss : 0.01093
# Epoch : 400, loss : 0.01069
# Epoch : 0, loss : 0.48461
# Epoch : 100, loss : 0.03241
# Epoch : 200, loss : 0.03047
# Epoch : 300, loss : 0.03042
# Epoch : 400, loss : 0.03039
# Epoch : 0, loss : 0.47831
# Epoch : 100, loss : 0.00378
# Epoch : 200, loss : 0.00144
# Epoch : 300, loss : 0.00096
# Epoch : 400, loss : 0.00070
# Epoch : 0, loss : 0.48703
# Epoch : 100, loss : 0.00149
# Epoch : 200, loss : 0.00082
# Epoch : 300, loss : 0.00065
# Epoch : 400, loss : 0.00056
# Epoch : 0, loss : 0.44382
# Epoch : 100, loss : 0.09579
# Epoch : 200, loss : 0.09579
# Epoch : 300, loss : 0.09579
# Epoch : 400, loss : 0.09579
# Epoch : 0, loss : 0.37858
# Epoch : 100, loss : 0.00168
# Epoch : 200, loss : 0.00157
# Epoch : 300, loss : 0.00155
# Epoch : 400, loss : 0.00153
# Epoch : 0, loss : 0.51058
# Epoch : 100, loss : 0.08792
# Epoch : 200, loss : 0.08792
# Epoch : 300, loss : 0.08792
# Epoch : 400, loss : 0.08792
# Epoch : 0, loss : 0.28662
# Epoch : 100, loss : 0.00938
# Epoch : 200, loss : 0.00757
# Epoch : 300, loss : 0.00761
# Epoch : 400, loss : 0.00780
# Epoch : 0, loss : 0.57804
# Epoch : 100, loss : 0.00121
# Epoch : 200, loss : 0.00087
# Epoch : 300, loss : 0.00098
# Epoch : 400, loss : 0.00070
# Epoch : 0, loss : 0.49199
# Epoch : 100, loss : 0.00435
# Epoch : 200, loss : 0.00277
# Epoch : 300, loss : 0.00167
# Epoch : 400, loss : 0.00095

# %%
result.drop()
# Out:
#       test     수원시     성남시    의정부시     안양시      부천시     광명시      평택시     동두천시  \
# MAE      0 2.39925 3.25591 2.02854 3.02049 10.04844 4.93418 13.82369  4.65145
# RMSE     0 3.48003 4.38387 3.13609 3.74859 11.17379 5.41553 14.82377  5.22569
# MAPE     0 0.99608 0.99608 0.99608 0.99608  0.99608 0.99608  0.99608  0.99608
# R2       0 0.93563 0.65549 0.89957 0.91530  0.00000 0.80085  0.00000 -1.00471
#
#           안산시  ...     이천시     안성시     김포시     화성시      광주시     양주시     여주시  \
# MAE  15.87973  ... 1.99048 2.06770 5.30830 4.48867  9.29562 1.85301 3.29465
# RMSE 17.15526  ... 2.85034 2.26310 6.64486 4.95712 10.16954 2.29250 3.66232
# MAPE  0.99608  ... 0.99608 0.99608 0.99608 0.99608  0.99608 0.99608 0.99608
# R2    0.00000  ... 0.82487 0.92992 0.22800 0.75118  0.00000 0.94063 0.00000
#
#          포천시     의왕시       오산시
# MAE  0.66280 2.56679  11.29667
# RMSE 0.86425 3.50358  13.50078
# MAPE 0.99608 0.99608   0.99608
# R2   0.96641 0.95156 -17.58646
#
# [4 rows x 29 columns]

# %%
#Figure

plt.figure(figsize = (10,6)) # Plotting
plt.plot(real_data, label = 'Real Data')
plt.plot(predict_data, label = 'predicted data')
plt.title('Time series prediction')
plt.legend()
plt.show()

# %%
for i in range(26,27):
    cluster = int(df[df.columns[i]][-1])
    answer = []
    for num in range(11):
        if abs(train.corr()['Avg_{}'.format(cluster+1)][num])>=0.7:
            answer.append(num)
    
    col =[]
    for j in  answer:
        col.append(train.columns[j])
    train[col]
    x = train[col].replace(',','')
    y = df.iloc[:-1,i:i+1]
    
    
    # Data Division

    train_x = x.iloc[0:int(len(df)*Train_ratio),:]

    train_y = y.iloc[0:int(len(df)*Train_ratio),:]

    test_x = x.iloc[int(len(df)*Train_ratio):,:]

    test_y = y.iloc[int(len(df)*Train_ratio):,:]
    
train_x
# Out:
#               seoul    Avg_1    Avg_3      CPI    대출금리  전세가격지수 전국   \
# date
# 2013-01-01 73.50000 64.75625 80.10000 92.72800 5.78000    82.68933
# 2013-02-01 73.20000 64.42500 79.80000 93.03800 5.66000    82.87118
# 2013-03-01 73.10000 64.22500 79.60000 92.95200 5.54000    83.16272
# 2013-04-01 73.20000 64.30000 79.50000 92.82300 5.42000    83.55404
# 2013-05-01 73.40000 64.49375 79.60000 92.82300 5.24000    83.79708
# ...             ...      ...      ...      ...     ...         ...
# 2019-01-01 92.40000 77.43750 83.70000 98.88400 4.21000    93.58385
# 2019-02-01 92.10000 77.23750 83.60000 99.31100 4.18000    93.37628
# 2019-03-01 91.70000 76.88125 83.50000 99.12100 4.22000    93.14546
# 2019-04-01 91.40000 76.39375 83.20000 99.48100 4.16000    92.87534
# 2019-05-01 91.20000 76.03750 82.90000 99.65200 4.14000    92.67329
#
#             전세가격지수 경기도         M2
# date
# 2013-01-01    76.00764 1841.10000
# 2013-02-01    76.10804 1857.10000
# 2013-03-01    76.37669 1862.40000
# 2013-04-01    76.85819 1867.70000
# 2013-05-01    77.09053 1870.30000
# ...                ...        ...
# 2019-01-01    90.97146 2717.00000
# 2019-02-01    90.74905 2730.00000
# 2019-03-01    90.46364 2753.00000
# 2019-04-01    90.03024 2763.00000
# 2019-05-01    89.75179 2772.00000
#
# [77 rows x 8 columns]

# %%
    # Normalizing , 둘다 학습하여 성능비교할것

    minmax = MinMaxScaler()

    standard = StandardScaler()



    train_x = minmax.fit_transform(train_x)

    train_y = minmax.fit_transform(train_y)

    test_x = minmax.fit_transform(test_x)

    test_y = minmax.fit_transform(test_y)





    # Numpy array상태로는 학습이 불가능하므로, Torch Variable 형태로 변경(data/grad/grad_fn)

    train_x_tensor = Variable(torch.Tensor(train_x))

    train_y_tensor = Variable(torch.Tensor(train_y))

    

    test_x_tensor = Variable(torch.Tensor(test_x))

    test_y_tensor = Variable(torch.Tensor(test_y))

    

    train_x_tensor_final = torch.reshape(train_x_tensor, (train_x_tensor.shape[0], 1, train_x_tensor.shape[1]))

    train_y_tensor_final = torch.reshape(train_y_tensor, (train_y_tensor.shape[0], 1, train_y_tensor.shape[1]))

    test_x_tensor_final = torch.reshape(test_x_tensor, (test_x_tensor.shape[0], 1, test_x_tensor.shape[1]))

    test_y_tensor_final = torch.reshape(test_y_tensor,(test_y_tensor.shape[0], 1, test_y_tensor.shape[1]) )

    


    ## LSTM network modeling

    class LSTM_Jun(nn.Module):

        def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length) : 

            super(LSTM_Jun, self).__init__()

            self.num_classes = num_classes

            self.num_layers = num_layers

            self.input_size = input_size

            self.hidden_size = hidden_size

            self.seq_length = seq_length

            self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = num_layers, batch_first = True)

            self.layer_1 = nn.Linear(hidden_size, 256)

            self.layer_2 = nn.Linear(256,256)

            self.layer_3 = nn.Linear(256,128)

            self.layer_out = nn.Linear(128, num_classes)

            self.relu = nn.ReLU() #Activation Func



        def forward(self,x):

            h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device) #Hidden State

            c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device) #Internal Process States



            output, (hn, cn) = self.lstm(x, (h_0, c_0))



            hn = hn.view(-1, self.hidden_size) # Reshaping the data for starting LSTM network

            out = self.relu(hn) #pre-processing for first layer

            out = self.layer_1(out) # first layer

            out = self.relu(out) # activation func relu

            out = self.layer_2(out)

            out = self.relu(out)

            out = self.layer_3(out)

            out = self.relu(out)

            out = self.layer_out(out) #Output layer

            return out

 

    # Code Main

    num_epochs = 500
    learning_rate = 0.005

    input_size = int(len(x.columns))

    hidden_size = 2 # number of features in hidden state

    num_layers = 1

    num_classes = int(len(y.columns))



    LSTM_Jun = LSTM_Jun(num_classes, input_size, hidden_size, num_layers, train_x_tensor_final.shape[1]).to(device)



    loss_function = torch.nn.MSELoss()

    optimizer = torch.optim.Adam(LSTM_Jun.parameters(), lr = learning_rate)

 

    for epoch in range(num_epochs) : 

        outputs = LSTM_Jun.forward(train_x_tensor_final.to(device))

        optimizer.zero_grad()

        loss = loss_function(outputs, train_y_tensor.to(device))

        loss.backward()

        optimizer.step() # improve from loss = back propagation

        if epoch % 100 == 0 :

            print("Epoch : %d, loss : %1.5f" % (epoch, loss.item()))
            

    # Estimated Value

    test_predict = LSTM_Jun(test_x_tensor_final.to(device)) #Forward Pass

    predict_data = test_predict.data.detach().cpu().numpy() #numpy conversion

    predict_data = minmax.inverse_transform(predict_data) #inverse normalization(Min/Max)
    

    # Real Value

    real_data = test_y_tensor.data.numpy() # Real value

    real_data = minmax.inverse_transform(real_data) #inverse normalization 
    
    from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

    
    MAE = mean_absolute_error(predict_data, real_data)
    RMSE = np.sqrt(mean_squared_error(predict_data, real_data))
    R2 = r2_score(predict_data, real_data)
    MAPE= np.mean(np.abs((y_test - y_pred) / y_test))
    pd.options.display.float_format = '{:.5f}'.format
    label = df.columns[i]
    Result = pd.DataFrame(data=[MAE,RMSE, MAPE,R2],
                         index = ['MAE','RMSE','MAPE','R2'],
                         columns=[label])
        
    

    result = pd.concat([result,Result],axis = 1)
# Out:
# Epoch : 0, loss : 0.40617
# Epoch : 100, loss : 0.00084
# Epoch : 200, loss : 0.00043
# Epoch : 300, loss : 0.00037
# Epoch : 400, loss : 0.00031

# %%
#Figure

plt.figure(figsize = (10,6)) # Plotting
plt.plot(real_data, label = 'Real Data')
plt.plot(predict_data, label = 'predicted data')
plt.title('Time series prediction')
plt.legend()
plt.show()
