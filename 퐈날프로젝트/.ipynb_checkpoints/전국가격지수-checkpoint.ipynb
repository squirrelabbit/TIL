# %% [markdown]
# # 1. 클러스터링

# %%
import pandas as pd
import numpy as np
import math

#Visualizing
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'; plt.rcParams['axes.unicode_minus'] = False;
import seaborn as sns; #sns.set_style('whitegrid')

#Time Series Analysis
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss, ccf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

#Clustering (+α)
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from minisom import MiniSom

#Modeling
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

#System
from ipywidgets import interact
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %% [markdown]
# ## 경기도 클러스터링

# %%
data = pd.read_csv('전국 가격지수.csv',index_col=0,encoding = 'cp949')
data
# Out:
#                  행정구역별 [Item]항목         항목  단위  2003.11 월  2003.12 월  \
# [region]행정구역별
# a0                  전국    sales  아파트매매가격지수 NaN  55.408061  55.092318
# a7               서울특별시    sales  아파트매매가격지수 NaN  52.489325  52.091964
# a7010101           종로구    sales  아파트매매가격지수 NaN  56.536446  56.416567
# a7010102            중구    sales  아파트매매가격지수 NaN  60.116747  59.542547
# a7010103           용산구    sales  아파트매매가격지수 NaN  49.587010  49.347822
# ...                ...      ...        ...  ..        ...        ...
# c708               거제시    sales  아파트매매가격지수 NaN  64.408422  67.016026
# c709               양산시    sales  아파트매매가격지수 NaN  69.000908  67.930278
# c8             제주특별자치도    sales  아파트매매가격지수 NaN  53.577593  53.498832
# c801               제주시    sales  아파트매매가격지수 NaN  52.789339  52.711736
# c802              서귀포시    sales  아파트매매가격지수 NaN        NaN        NaN
#
#                2004.01 월  2004.02 월  2004.03 월  2004.04 월  ...   2021.07 월  \
# [region]행정구역별                                              ...
# a0             54.959520  55.144495  55.364299  55.599180  ...  101.206901
# a7             51.936493  52.246176  52.519256  52.863347  ...  100.811666
# a7010101       56.279525  56.587524  56.628455  57.196030  ...  100.389827
# a7010102       59.606992  59.845321  60.050523  60.276372  ...  100.377028
# a7010103       49.607329  50.300318  50.800629  51.898263  ...  100.636426
# ...                  ...        ...        ...        ...  ...         ...
# c708           66.482205  68.966144  70.116246  69.993438  ...  100.674074
# c709           67.658008  67.542576  67.711941  67.900468  ...  100.873089
# c8             53.601192  53.541693  53.491140  53.652920  ...  101.898235
# c801           52.812591  52.753967  52.704158  52.863558  ...  102.146529
# c802                 NaN        NaN        NaN        NaN  ...  101.123340
#
#                 2021.08 월   2021.09 월   2021.10 월   2021.11 월   2021.12 월  \
# [region]행정구역별
# a0             102.567185  103.787444  105.016629  105.856641  106.203727
# a7             101.739971  102.657125  103.504915  104.121909  104.377172
# a7010101       101.181645  101.847102  102.756382  103.486567  103.652827
# a7010102       101.003355  101.654878  102.575399  103.310747  103.462553
# a7010103       101.597995  102.569165  103.851584  105.020062  105.512652
# ...                   ...         ...         ...         ...         ...
# c708           101.686253  102.396701  103.354363  104.139502  104.383379
# c709           102.134464  103.407351  104.601875  105.275329  105.622073
# c8             104.234108  105.610944  107.084376  108.223936  108.810295
# c801           104.943831  106.462756  108.166676  109.364632  110.013849
# c802           102.038966  102.983100  103.759370  104.722624  105.119962
#
#                 2022.01 월   2022.02 월   2022.03 월  Unnamed: 226
# [region]행정구역별
# a0             106.284037  106.262040  106.203239           NaN
# a7             104.382212  104.296694  104.223178           NaN
# a7010101       103.622889  103.377745  103.226713           NaN
# a7010102       103.472794  103.389724  103.256276           NaN
# a7010103       105.608657  105.564649  105.530053           NaN
# ...                   ...         ...         ...           ...
# c708           104.566506  104.774017  105.179828           NaN
# c709           105.862045  106.084281  106.330705           NaN
# c8             109.174082  109.460336  109.690956           NaN
# c801           110.426739  110.726979  110.983133           NaN
# c802           105.336422  105.580599  105.734687           NaN
#
# [173 rows x 226 columns]

# %%
# 클러스터 돌리기 전 변수를 생성 
df = data.copy()

# %% [markdown]
# ## 군집 개수 정하기

# %% [markdown]
# ### 1. elbow method

# %%
# 적절한 군집수 찾기 
# Inertia(군집 내 거리제곱합의 합) value (적정 군집수) 
ks = range(1,10) 
inertias = [] 
for k in ks: 
    model = TimeSeriesKMeans(n_clusters=k, metric="dtw",random_state = 2022)
    model.fit(df) 
    inertias.append(model.inertia_) 
    # Plot ks vs inertias 
plt.figure(figsize=(4, 4)) 
plt.plot(ks, inertias, '-o') 
plt.xlabel('number of clusters, k') 
plt.ylabel('inertia') 
plt.xticks(ks) 
plt.show()

# %% [markdown]
# ### 2. silhouette 계수

# %%
import numpy as np
from sklearn.metrics import silhouette_samples
from sklearn.datasets import make_blobs
from matplotlib import cm

def plotSilhouette(X, y_km):
    cluster_labels = np.unique(y_km)
    n_clusters = cluster_labels.shape[0]
    silhouette_vals = silhouette_samples(X, y_km, metric = 'euclidean')
    y_ax_lower, y_ax_upper = 0, 0
    yticks = []

    for i, c in enumerate(cluster_labels):
        c_silhouette_vals = silhouette_vals[y_km == c]
        c_silhouette_vals.sort()
        y_ax_upper += len(c_silhouette_vals)
        color = cm.jet(i/n_clusters)

        plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, height=1.0,
                edgecolor='none', color=color)
        yticks.append((y_ax_lower + y_ax_upper)/2)
        y_ax_lower += len(c_silhouette_vals)

    silhoutte_avg = np.mean(silhouette_vals)
    plt.axvline(silhoutte_avg, color = 'red', linestyle='--')
    plt.yticks(yticks, cluster_labels+1)
    plt.ylabel('K')
    plt.xlabel('실루엣 계수')
    plt.show()

# %%
k= 2

X, y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std=0.5,
                  shuffle=True, random_state=0)
km = TimeSeriesKMeans(n_clusters=k, metric="dtw",random_state = 2022)
y_km = km.fit_predict(df)
plotSilhouette(df, y_km)

# %%
k= 3

X, y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std=0.5,
                  shuffle=True, random_state=0)
km = TimeSeriesKMeans(n_clusters=k, metric="dtw",random_state = 2022)
y_km = km.fit_predict(df)
plotSilhouette(df, y_km)

# %%
k= 4

X, y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std=0.5,
                  shuffle=True, random_state=0)
km = TimeSeriesKMeans(n_clusters=k, metric="dtw",random_state = 2022)
y_km = km.fit_predict(df)
plotSilhouette(df, y_km)

# %% [markdown]
# ## 클러스터별 저장

# %%
# K-Means 모델과 군집 예측값을 생성 
# 클러스터 모델 생성 파라미터는 원할 경우 추가 
model =  TimeSeriesKMeans(n_clusters=2, metric="dtw", random_state = 2022)
                     # 클러스터 갯수 
                     # , n_init=10 
                     # initial centroid를 몇번 샘플링한건지, 데이터가 많으면 많이 돌릴수록안정화된 결과가 나옴 
                     # , max_iter=500 # KMeans를 몇번 반복 수행할건지, K가 큰 경우 1000정도로 높여준다 
                     #random_state = 42 # , algorithm='auto' ) 
 # 생성한 모델로 데이터를 학습시킴 
model.fit(df) # unsupervised learning 
# 결과 값을 변수에 저장 
df['cluster'] = model.fit_predict(df)

# %%
df.to_csv('경기도_clustered.csv',encoding='utf-8')

# %%
df0= df.loc[df['cluster'] == 0]
df0
# Out:
#        2013-01-01  2013-02-01  2013-03-01  2013-04-01  2013-05-01  2013-06-01  \
# 행정구역별
# 수원시          63.4        63.3        63.2        63.3        63.4        63.5
# 성남시          67.8        67.2        66.9        67.1        67.5        67.9
# 의정부시         77.7        77.4        76.9        76.4        76.4        76.2
# 안양시          60.5        60.2        60.0        59.8        59.6        59.5
# 부천시          68.1        67.7        67.4        67.4        67.6        67.6
# 광명시          53.0        52.9        52.6        52.6        52.9        53.0
# 안산시          66.8        66.6        66.3        66.3        66.6        66.8
# 고양시          69.5        69.0        68.6        68.1        68.1        68.0
# 과천시          63.4        63.1        63.2        64.5        64.8        64.6
# 구리시          58.9        58.3        58.0        58.1        58.3        58.4
# 남양주시         70.2        69.9        69.7        69.6        69.7        69.6
# 시흥시          67.8        67.2        67.1        67.0        67.2        67.3
# 군포시          64.5        64.5        64.4        64.8        65.0        65.2
# 하남시          62.6        62.4        62.3        62.5        62.9        62.8
# 용인시          68.8        68.5        68.4        68.4        68.5        68.7
# 김포시          71.1        70.9        70.8        70.7        71.0        70.8
# 화성시          73.0        72.9        72.8        73.2        73.6        73.7
# 의왕시          59.7        59.1        58.7        58.6        58.8        59.1
#
#        2013-07-01  2013-08-01  2013-09-01  2013-10-01  ...  2021-06-01  \
# 행정구역별                                                  ...
# 수원시          63.4        63.2        63.2        63.4  ...       100.0
# 성남시          67.7        67.4        67.4        67.5  ...       100.0
# 의정부시         75.5        75.2        75.1        75.2  ...       100.0
# 안양시          59.5        59.4        59.5        59.8  ...       100.0
# 부천시          67.5        67.2        67.2        67.8  ...       100.0
# 광명시          53.1        52.9        53.1        53.1  ...       100.0
# 안산시          66.7        66.5        66.6        66.9  ...       100.0
# 고양시          67.9        67.9        68.1        68.5  ...       100.0
# 과천시          64.3        64.0        64.0        64.5  ...       100.0
# 구리시          58.3        58.2        58.2        58.6  ...       100.0
# 남양주시         69.4        69.2        69.1        69.3  ...       100.0
# 시흥시          67.3        67.1        67.3        67.7  ...       100.0
# 군포시          64.7        64.5        65.1        65.8  ...       100.0
# 하남시          62.7        62.5        62.7        63.6  ...       100.0
# 용인시          68.5        68.4        68.2        68.3  ...       100.0
# 김포시          70.2        69.8        69.9        71.3  ...       100.0
# 화성시          73.4        73.2        73.2        73.6  ...       100.0
# 의왕시          58.7        58.6        58.8        59.3  ...       100.0
#
#        2021-07-01  2021-08-01  2021-09-01  2021-10-01  2021-11-01  2021-12-01  \
# 행정구역별
# 수원시         102.4       104.7       106.5       108.4       109.5       109.8
# 성남시         101.3       102.6       103.6       104.3       104.8       105.1
# 의정부시        101.8       103.8       105.2       106.5       107.2       107.4
# 안양시         103.2       106.2       108.3       110.5       111.7       112.0
# 부천시         102.0       104.5       106.7       108.7       110.2       110.8
# 광명시         102.0       104.0       105.5       106.7       107.3       107.4
# 안산시         102.8       105.0       107.1       109.3       110.7       111.2
# 고양시         101.4       103.1       105.0       106.7       107.6       108.0
# 과천시         100.8       101.8       102.3       102.6       103.1       103.5
# 구리시         101.2       102.7       104.0       105.3       106.2       106.4
# 남양주시        101.9       104.1       106.1       107.8       108.9       109.3
# 시흥시         103.2       106.3       109.1       111.4       112.7       113.1
# 군포시         103.6       107.1       110.0       112.4       114.1       114.8
# 하남시         100.6       101.7       102.3       102.8       103.2       103.2
# 용인시         101.4       103.4       104.9       106.2       107.1       107.5
# 김포시         100.2       101.4       102.7       104.7       105.3       105.6
# 화성시         102.5       105.6       108.8       110.9       111.6       111.6
# 의왕시         103.1       106.4       109.1       111.5       112.9       113.0
#
#        2022-01-01  2022-02-01  cluster
# 행정구역별
# 수원시         109.8       109.6        0
# 성남시         105.1       105.0        0
# 의정부시        107.4       107.3        0
# 안양시         111.8       111.6        0
# 부천시         110.8       110.7        0
# 광명시         107.3       107.3        0
# 안산시         111.3       111.3        0
# 고양시         108.1       108.0        0
# 과천시         103.4       103.4        0
# 구리시         106.3       106.3        0
# 남양주시        109.3       109.3        0
# 시흥시         112.9       112.6        0
# 군포시         114.7       114.6        0
# 하남시         103.0       102.8        0
# 용인시         107.6       107.4        0
# 김포시         105.6       105.6        0
# 화성시         111.5       111.0        0
# 의왕시         113.0       112.9        0
#
# [18 rows x 111 columns]

# %%
df0.to_csv('cluster0.csv',encoding='utf-8')

# %%
df1= df.loc[df['cluster'] == 1]
df1
# Out:
#        2013-01-01  2013-02-01  2013-03-01  2013-04-01  2013-05-01  2013-06-01  \
# 행정구역별
# 평택시          92.6        92.5        92.4        92.4        92.4        92.6
# 동두천시         92.6        90.9        90.1        90.0        89.8        89.6
# 파주시          82.3        81.9        81.6        80.6        80.7        80.3
# 이천시          89.2        89.4        89.7        90.1        90.4        90.6
# 안성시          92.6        92.8        92.8        93.5        93.8        94.1
# 광주시          82.4        82.0        81.9        82.3        82.3        82.2
# 양주시          82.0        81.7        81.4        81.7        81.9        82.1
# 여주시         102.8       102.8       102.7       102.7       103.6       103.8
# 포천시          93.6        93.6        93.6        93.9        94.7        95.1
# 오산시          83.2        83.0        82.9        82.9        82.9        82.4
#
#        2013-07-01  2013-08-01  2013-09-01  2013-10-01  ...  2021-06-01  \
# 행정구역별                                                  ...
# 평택시          92.5        92.3        92.3        92.4  ...       100.0
# 동두천시         89.3        89.0        88.9        89.0  ...       100.0
# 파주시          80.0        80.0        80.4        80.7  ...       100.0
# 이천시          90.7        90.8        91.0        91.5  ...       100.0
# 안성시          94.3        94.4        94.7        95.3  ...       100.0
# 광주시          81.9        81.6        81.4        81.5  ...       100.0
# 양주시          81.4        81.0        81.0        81.3  ...       100.0
# 여주시         103.9       103.8       103.8       104.3  ...       100.0
# 포천시          94.7        94.2        93.8        94.1  ...       100.0
# 오산시          82.1        81.9        81.7        81.8  ...       100.0
#
#        2021-07-01  2021-08-01  2021-09-01  2021-10-01  2021-11-01  2021-12-01  \
# 행정구역별
# 평택시         103.0       106.2       108.8       111.7       113.2       114.1
# 동두천시        102.0       104.5       106.4       107.3       107.7       107.5
# 파주시         101.1       103.1       104.7       105.9       106.9       107.2
# 이천시         101.6       103.3       105.3       107.8       110.3       112.3
# 안성시         103.7       106.9       109.9       112.6       114.8       116.1
# 광주시         101.8       104.1       105.4       106.8       107.9       108.4
# 양주시         101.8       104.2       106.4       108.5       109.5       109.8
# 여주시         101.1       102.4       103.5       105.2       106.6       107.2
# 포천시         101.6       103.7       105.8       107.3       108.4       109.0
# 오산시         103.5       107.3       110.7       114.1       115.9       116.7
#
#        2022-01-01  2022-02-01  cluster
# 행정구역별
# 평택시         114.3       114.3        1
# 동두천시        107.5       107.4        1
# 파주시         107.5       107.8        1
# 이천시         113.3       114.2        1
# 안성시         116.9       117.0        1
# 광주시         108.7       108.7        1
# 양주시         109.8       109.7        1
# 여주시         107.1       107.1        1
# 포천시         109.2       109.3        1
# 오산시         116.8       116.6        1
#
# [10 rows x 111 columns]

# %%
df1.to_csv('cluster1.csv',encoding='utf-8')

# %%
df2= df.loc[df['cluster'] == 2]
df2.to_csv('cluster2.csv',encoding='utf-8')

# %% [markdown]
# ## 클러스터별 상관관계

# %%
data_S = pd.read_csv('서울시 가격지수.csv',index_col = 0)
data_S = data_S.T
data_S
# Out:
# date        seoul
# 2013-01-01   73.5
# 2013-02-01   73.2
# 2013-03-01   73.1
# 2013-04-01   73.2
# 2013-05-01   73.4
# ...           ...
# 2021-10-01  103.5
# 2021-11-01  104.1
# 2021-12-01  104.4
# 2022-01-01  104.4
# 2022-02-01  104.3
#
# [110 rows x 1 columns]

# %%
data_S['cluster1'] = df0.mean()
data_S['cluster2'] = df1.mean()

data_S
# Out:
# date        seoul    cluster1  cluster2
# 2013-01-01   73.5   65.933333     89.33
# 2013-02-01   73.2   65.616667     89.06
# 2013-03-01   73.1   65.405556     88.91
# 2013-04-01   73.2   65.466667     89.01
# 2013-05-01   73.4   65.661111     89.25
# ...           ...         ...       ...
# 2021-10-01  103.5  107.594444    108.72
# 2021-11-01  104.1  108.561111    110.12
# 2021-12-01  104.4  108.872222    110.83
# 2022-01-01  104.4  108.827778    111.11
# 2022-02-01  104.3  108.705556    111.21
#
# [110 rows x 3 columns]

# %%
data_S.corr()
# Out:
# date         seoul  cluster1  cluster2
# date
# seoul     1.000000  0.904728  0.521873
# cluster1  0.904728  1.000000  0.746767
# cluster2  0.521873  0.746767  1.000000
